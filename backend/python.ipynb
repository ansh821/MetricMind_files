# %%
from query_engine import get_total_summary

get_total_summary()
# Out:
# {'revenue': 12642905.0, 'profit': 1467457.2912799867, 'profit_margin': 11.61}

# %%
from query_engine import get_revenue_by_region

get_revenue_by_region()
# Out:
# [{'region': 'Central', 'revenue': 2822399.0},
#  {'region': 'South', 'revenue': 1600960.0},
#  {'region': 'North', 'revenue': 1248192.0},
#  {'region': 'Oceania', 'revenue': 1100207.0},
#  {'region': 'Southeast Asia', 'revenue': 884438.0},
#  {'region': 'North Asia', 'revenue': 848349.0},
#  {'region': 'EMEA', 'revenue': 806184.0},
#  {'region': 'Africa', 'revenue': 783776.0},
#  {'region': 'Central Asia', 'revenue': 752839.0},
#  {'region': 'West', 'revenue': 725514.0},
#  {'region': 'East', 'revenue': 678834.0},
#  {'region': 'Caribbean', 'revenue': 324281.0},
#  {'region': 'Canada', 'revenue': 66932.0}]
